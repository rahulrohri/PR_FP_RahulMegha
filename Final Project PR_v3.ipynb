# %%
import pandas as pd

# %%
complaints_df = pd.read_csv('C:/Users/megha/Downloads/NYPD_Complaint_Data_Historic.csv',low_memory = False)

# %%
complaints_df.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0   522575447   08/29/2006     13:00:00          NaN          NaN
# 1   403507361   11/05/2006     11:00:00   11/05/2006     17:40:00
# 2   631420068   09/08/2006     23:30:00   09/09/2006     00:01:00
# 3   995609899   12/13/2011     18:40:00   12/13/2011     18:49:00
# 4   480667624   08/14/2009     04:20:00          NaN          NaN
#
#    ADDR_PCT_CD      RPT_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 0         43.0  08/30/2006    578                   HARRASSMENT 2  638.0
# 1         66.0  11/05/2006    107                        BURGLARY  221.0
# 2        106.0  09/09/2006    347  INTOXICATED & IMPAIRED DRIVING  905.0
# 3         79.0  12/13/2011    341                   PETIT LARCENY  333.0
# 4         30.0  08/14/2009    113                         FORGERY  729.0
#
#                           PD_DESC CRM_ATPT_CPTD_CD   LAW_CAT_CD    BORO_NM  \
# 0           HARASSMENT,SUBD 3,4,5        COMPLETED    VIOLATION      BRONX
# 1          BURGLARY,RESIDENCE,DAY        COMPLETED       FELONY   BROOKLYN
# 2     INTOXICATED DRIVING,ALCOHOL        COMPLETED  MISDEMEANOR     QUEENS
# 3  LARCENY,PETIT FROM STORE-SHOPL        COMPLETED  MISDEMEANOR   BROOKLYN
# 4  FORGERY,ETC.,UNCLASSIFIED-FELO        COMPLETED       FELONY  MANHATTAN
#
#   LOC_OF_OCCUR_DESC           PREM_TYP_DESC        JURIS_DESC  \
# 0            INSIDE  RESIDENCE - APT. HOUSE  N.Y. POLICE DEPT
# 1            INSIDE  RESIDENCE - APT. HOUSE  N.Y. POLICE DEPT
# 2          FRONT OF                  STREET  N.Y. POLICE DEPT
# 3            INSIDE             CHAIN STORE  N.Y. POLICE DEPT
# 4               NaN                  STREET  N.Y. POLICE DEPT
#
#    JURISDICTION_CODE PARKS_NM HADEVELOPT HOUSING_PSA  X_COORD_CD  Y_COORD_CD  \
# 0                0.0      NaN        NaN         NaN   1018029.0    240747.0
# 1                0.0      NaN        NaN         NaN    982556.0    171385.0
# 2                0.0      NaN        NaN         NaN   1028213.0    186786.0
# 3                0.0      NaN        NaN         NaN   1000788.0    189718.0
# 4                0.0      NaN        NaN         NaN   1000029.0    242245.0
#
#   SUSP_AGE_GROUP SUSP_RACE SUSP_SEX  TRANSIT_DISTRICT   Latitude  Longitude  \
# 0            NaN   UNKNOWN        M               NaN  40.827414 -73.877946
# 1            NaN       NaN      NaN               NaN  40.637097 -74.006105
# 2            NaN       NaN      NaN               NaN  40.679260 -73.841500
# 3            NaN       NaN      NaN               NaN  40.687402 -73.940369
# 4            NaN       NaN      NaN               NaN  40.831576 -73.942983
#
#                          Lat_Lon               PATROL_BORO STATION_NAME  \
# 0  (40.827414051, -73.877945775)         PATROL BORO BRONX          NaN
# 1  (40.637096864, -74.006105014)   PATROL BORO BKLYN SOUTH          NaN
# 2  (40.679260229, -73.841500185)  PATROL BORO QUEENS SOUTH          NaN
# 3  (40.687401619, -73.940369194)   PATROL BORO BKLYN NORTH          NaN
# 4  (40.831576128, -73.942982699)     PATROL BORO MAN NORTH          NaN
#
#   VIC_AGE_GROUP                  VIC_RACE VIC_SEX
# 0         25-44            BLACK HISPANIC       F
# 1         45-64  ASIAN / PACIFIC ISLANDER       F
# 2           NaN                   UNKNOWN       E
# 3           NaN                   UNKNOWN       D
# 4           NaN                   UNKNOWN       E

# %%
#complaints_df.columns
#complaints_df.OFNS_DESC.unique()
#complaints_df.VIC_RACE.unique()

# %%
pd.set_option("display.max_rows",404)

# %%
complaints_df.VIC_RACE = complaints_df.VIC_RACE.fillna('UNKNOWN') #replacing nans with 'UNKNOWN'
complaints_df.VIC_RACE.unique()
complaints_df = complaints_df.replace({'VIC_RACE': 'UNKNOWN'}, 'UNKNOWN/OTHER')
complaints_df = complaints_df.replace({'VIC_RACE': 'OTHER'}, 'UNKNOWN/OTHER')

# %%
#Selecting particular crimes
type_of_crime = ['HARRASSMENT 2','BURGLARY','ROBBERY','FELONY ASSAULT','SEX CRIMES','OFFENSES INVOLVING FRAUD','RAPE','THEFT-FRAUD','MURDER & NON-NEGL. MANSLAUGHTER','KIDNAPPING & RELATED OFFENSES','OFFENSES RELATED TO CHILDREN','KIDNAPPING','OTHER OFFENSES RELATED TO THEF','PETIT LARCENY','GRAND LARCENY','FORGERY','FRAUDS','ASSAULT 3 & RELATED OFFENSES']
#https://cmdlinetips.com/2018/02/how-to-subset-pandas-dataframe-based-on-values-of-a-column/
complaints_df_new =complaints_df[complaints_df.OFNS_DESC.isin(type_of_crime)]
complaints_df_new
#complaints_df_new.OFNS_DESC.unique()
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0         522575447   08/29/2006     13:00:00          NaN          NaN
# 1         403507361   11/05/2006     11:00:00   11/05/2006     17:40:00
# 3         995609899   12/13/2011     18:40:00   12/13/2011     18:49:00
# 4         480667624   08/14/2009     04:20:00          NaN          NaN
# 5         605915885   10/27/2009     21:10:00          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 6847932   872275533   07/22/2017     13:15:00   07/22/2017     13:25:00
# 6847939   954636350   08/23/2015     02:00:00   08/23/2015     02:10:00
# 6847940   960069040   06/15/2013     11:30:00   06/15/2013     11:35:00
# 6847941   131686727   07/12/2012     14:00:00   07/12/2012     14:05:00
# 6847942   443513715   04/15/2012     19:00:00   04/16/2012     08:00:00
#
#          ADDR_PCT_CD      RPT_DT  KY_CD       OFNS_DESC  PD_CD  \
# 0               43.0  08/30/2006    578   HARRASSMENT 2  638.0
# 1               66.0  11/05/2006    107        BURGLARY  221.0
# 3               79.0  12/13/2011    341   PETIT LARCENY  333.0
# 4               30.0  08/14/2009    113         FORGERY  729.0
# 5               69.0  10/29/2009    105         ROBBERY  397.0
# ...              ...         ...    ...             ...    ...
# 6847932         18.0  07/22/2017    341   PETIT LARCENY  338.0
# 6847939         75.0  08/23/2015    340          FRAUDS  707.0
# 6847940         32.0  06/15/2013    578   HARRASSMENT 2  638.0
# 6847941         49.0  07/12/2012    106  FELONY ASSAULT  109.0
# 6847942        112.0  04/16/2012    341   PETIT LARCENY  321.0
#
#                                 PD_DESC CRM_ATPT_CPTD_CD   LAW_CAT_CD  \
# 0                 HARASSMENT,SUBD 3,4,5        COMPLETED    VIOLATION
# 1                BURGLARY,RESIDENCE,DAY        COMPLETED       FELONY
# 3        LARCENY,PETIT FROM STORE-SHOPL        COMPLETED  MISDEMEANOR
# 4        FORGERY,ETC.,UNCLASSIFIED-FELO        COMPLETED       FELONY
# 5        ROBBERY,OPEN AREA UNCLASSIFIED        COMPLETED       FELONY
# ...                                 ...              ...          ...
# 6847932  LARCENY,PETIT FROM BUILDING,UN        COMPLETED  MISDEMEANOR
# 6847939  IMPERSONATION 2, PUBLIC SERVAN        COMPLETED  MISDEMEANOR
# 6847940           HARASSMENT,SUBD 3,4,5        COMPLETED    VIOLATION
# 6847941        ASSAULT 2,1,UNCLASSIFIED        COMPLETED       FELONY
# 6847942         LARCENY,PETIT FROM AUTO        COMPLETED  MISDEMEANOR
#
#            BORO_NM LOC_OF_OCCUR_DESC               PREM_TYP_DESC  \
# 0            BRONX            INSIDE      RESIDENCE - APT. HOUSE
# 1         BROOKLYN            INSIDE      RESIDENCE - APT. HOUSE
# 3         BROOKLYN            INSIDE                 CHAIN STORE
# 4        MANHATTAN               NaN                      STREET
# 5         BROOKLYN          FRONT OF                      STREET
# ...            ...               ...                         ...
# 6847932  MANHATTAN            INSIDE                 HOTEL/MOTEL
# 6847939   BROOKLYN               NaN                      STREET
# 6847940  MANHATTAN            INSIDE  RESIDENCE - PUBLIC HOUSING
# 6847941      BRONX          FRONT OF                      STREET
# 6847942     QUEENS          FRONT OF                      STREET
#
#                   JURIS_DESC  JURISDICTION_CODE PARKS_NM HADEVELOPT  \
# 0           N.Y. POLICE DEPT                0.0      NaN        NaN
# 1           N.Y. POLICE DEPT                0.0      NaN        NaN
# 3           N.Y. POLICE DEPT                0.0      NaN        NaN
# 4           N.Y. POLICE DEPT                0.0      NaN        NaN
# 5           N.Y. POLICE DEPT                0.0      NaN        NaN
# ...                      ...                ...      ...        ...
# 6847932     N.Y. POLICE DEPT                0.0      NaN        NaN
# 6847939     N.Y. POLICE DEPT                0.0      NaN        NaN
# 6847940  N.Y. HOUSING POLICE                2.0      NaN        NaN
# 6847941     N.Y. POLICE DEPT                0.0      NaN        NaN
# 6847942     N.Y. POLICE DEPT                0.0      NaN        NaN
#
#         HOUSING_PSA  X_COORD_CD  Y_COORD_CD SUSP_AGE_GROUP SUSP_RACE SUSP_SEX  \
# 0               NaN   1018029.0    240747.0            NaN   UNKNOWN        M
# 1               NaN    982556.0    171385.0            NaN       NaN      NaN
# 3               NaN   1000788.0    189718.0            NaN       NaN      NaN
# 4               NaN   1000029.0    242245.0            NaN       NaN      NaN
# 5               NaN   1010598.0    173684.0            NaN     BLACK        M
# ...             ...         ...         ...            ...       ...      ...
# 6847932         NaN    987453.0    216762.0        UNKNOWN   UNKNOWN        M
# 6847939         NaN   1018767.0    184224.0            NaN       NaN      NaN
# 6847940        4552   1001752.0    241629.0            NaN   UNKNOWN        M
# 6847941         NaN   1024945.0    247745.0            NaN       NaN      NaN
# 6847942         NaN   1024851.0    204800.0            NaN       NaN      NaN
#
#          TRANSIT_DISTRICT   Latitude  Longitude  \
# 0                     NaN  40.827414 -73.877946
# 1                     NaN  40.637097 -74.006105
# 3                     NaN  40.687402 -73.940369
# 4                     NaN  40.831576 -73.942983
# 5                     NaN  40.643368 -73.905059
# ...                   ...        ...        ...
# 6847932               NaN  40.761646 -73.988439
# 6847939               NaN  40.672270 -73.875569
# 6847940               NaN  40.829882 -73.936758
# 6847941               NaN  40.846592 -73.852913
# 6847942               NaN  40.728720 -73.853513
#
#                                Lat_Lon               PATROL_BORO STATION_NAME  \
# 0        (40.827414051, -73.877945775)         PATROL BORO BRONX          NaN
# 1        (40.637096864, -74.006105014)   PATROL BORO BKLYN SOUTH          NaN
# 3        (40.687401619, -73.940369194)   PATROL BORO BKLYN NORTH          NaN
# 4        (40.831576128, -73.942982699)     PATROL BORO MAN NORTH          NaN
# 5        (40.643368102, -73.905059257)   PATROL BORO BKLYN SOUTH          NaN
# ...                                ...                       ...          ...
# 6847932   (40.761645718, -73.98843929)     PATROL BORO MAN SOUTH          NaN
# 6847939  (40.672269995, -73.875569231)   PATROL BORO BKLYN NORTH          NaN
# 6847940    (40.829882139, -73.9367581)     PATROL BORO MAN NORTH          NaN
# 6847941  (40.846592354, -73.852913364)         PATROL BORO BRONX          NaN
# 6847942  (40.728720422, -73.853512684)  PATROL BORO QUEENS NORTH          NaN
#
#         VIC_AGE_GROUP                  VIC_RACE VIC_SEX
# 0               25-44            BLACK HISPANIC       F
# 1               45-64  ASIAN / PACIFIC ISLANDER       F
# 3                 NaN             UNKNOWN/OTHER       D
# 4                 NaN             UNKNOWN/OTHER       E
# 5               18-24                     BLACK       M
# ...               ...                       ...     ...
# 6847932         25-44            WHITE HISPANIC       M
# 6847939           NaN             UNKNOWN/OTHER       E
# 6847940         45-64                     BLACK       M
# 6847941         18-24                     WHITE       M
# 6847942           NaN             UNKNOWN/OTHER       D
#
# [4388833 rows x 35 columns]

# %%
race_count = complaints_df_new.groupby(['OFNS_DESC','VIC_RACE']).agg({'OFNS_DESC': ['count']})
#https://pandas.pydata.org/pandas-docs/version/0.23.1/generated/pandas.core.groupby.DataFrameGroupBy.agg.html
#race_count = race_count.sort_values(by = 'OFNS_DESC',ascending = False)
race_count.index.name = None
#race_count.sort_values(['OFNS_DESC'], axis=0)
race_count
# Out:
#                                                                OFNS_DESC
#                                                                    count
# OFNS_DESC                       VIC_RACE
# ASSAULT 3 & RELATED OFFENSES    AMERICAN INDIAN/ALASKAN NATIVE      3724
#                                 ASIAN / PACIFIC ISLANDER           46057
#                                 BLACK                             277634
#                                 BLACK HISPANIC                     41888
#                                 UNKNOWN/OTHER                      49764
#                                 WHITE                              98708
#                                 WHITE HISPANIC                    200300
# BURGLARY                        AMERICAN INDIAN/ALASKAN NATIVE      1379
#                                 ASIAN / PACIFIC ISLANDER           20494
#                                 BLACK                              41857
#                                 BLACK HISPANIC                      5709
#                                 UNKNOWN/OTHER                      78953
#                                 WHITE                              55916
#                                 WHITE HISPANIC                     31511
# FELONY ASSAULT                  AMERICAN INDIAN/ALASKAN NATIVE       977
#                                 ASIAN / PACIFIC ISLANDER           13869
#                                 BLACK                             107491
#                                 BLACK HISPANIC                     15179
#                                 UNKNOWN/OTHER                      31072
#                                 WHITE                              29009
#                                 WHITE HISPANIC                     62877
# FORGERY                         AMERICAN INDIAN/ALASKAN NATIVE        81
#                                 ASIAN / PACIFIC ISLANDER             644
#                                 BLACK                               2011
#                                 BLACK HISPANIC                       427
#                                 UNKNOWN/OTHER                      62419
#                                 WHITE                               2389
#                                 WHITE HISPANIC                      1640
# FRAUDS                          AMERICAN INDIAN/ALASKAN NATIVE       119
#                                 ASIAN / PACIFIC ISLANDER            1964
#                                 BLACK                               6149
#                                 BLACK HISPANIC                       905
#                                 UNKNOWN/OTHER                      18358
#                                 WHITE                              10485
#                                 WHITE HISPANIC                      4559
# GRAND LARCENY                   AMERICAN INDIAN/ALASKAN NATIVE      3647
#                                 ASIAN / PACIFIC ISLANDER           57722
#                                 BLACK                             118193
#                                 BLACK HISPANIC                     16240
#                                 UNKNOWN/OTHER                     116627
#                                 WHITE                             194000
#                                 WHITE HISPANIC                     85405
# HARRASSMENT 2                   AMERICAN INDIAN/ALASKAN NATIVE      5588
#                                 ASIAN / PACIFIC ISLANDER           51171
#                                 BLACK                             318303
